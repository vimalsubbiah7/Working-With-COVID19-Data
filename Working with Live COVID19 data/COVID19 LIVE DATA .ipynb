# %% [markdown]
# # <center>Python World Map Geovisualization Dashboard using Covid Data

# %% [markdown]
# ### Import Libraries

# %%
import json
import folium
import requests
import mimetypes
import http.client
import pandas as pd
from folium.plugins import HeatMap
from pandas.io.json import json_normalize

# %% [markdown]
# ### Accessing Data via API

# %%
conn = http.client.HTTPSConnection("api.covid19api.com")
payload = ''
headers = {}
conn.request("GET", "/summary", payload, headers)
res = conn.getresponse()
data = res.read().decode('UTF-8')

# %% [markdown]
# ### Converting Data to JSON

# %%
covid1= json.loads(data)
covid1
# Out:
# {'Message': '',
#  'Global': {'NewConfirmed': 650337,
#   'TotalConfirmed': 56890297,
#   'NewDeaths': 11000,
#   'TotalDeaths': 1360290,
#   'NewRecovered': 372814,
#   'TotalRecovered': 36512596},
#  'Countries': [{'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 377,
#    'TotalConfirmed': 44228,
#    'NewDeaths': 5,
#    'TotalDeaths': 1650,
#    'NewRecovered': 55,
#    'TotalRecovered': 35350,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 786,
#    'TotalConfirmed': 30623,
#    'NewDeaths': 11,
#    'TotalDeaths': 657,
#    'NewRecovered': 349,
#    'TotalRecovered': 14565,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 1023,
#    'TotalConfirmed': 71652,
#    'NewDeaths': 18,
#    'TotalDeaths': 2224,
#    'NewRecovered': 636,
#    'TotalRecovered': 46962,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 6066,
#    'NewDeaths': 0,
#    'TotalDeaths': 76,
#    'NewRecovered': 72,
#    'TotalRecovered': 5127,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 212,
#    'TotalConfirmed': 14134,
#    'NewDeaths': 1,
#    'TotalDeaths': 333,
#    'NewRecovered': 439,
#    'TotalRecovered': 7062,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 139,
#    'NewDeaths': 0,
#    'TotalDeaths': 4,
#    'NewRecovered': 0,
#    'TotalRecovered': 127,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 10097,
#    'TotalConfirmed': 1349434,
#    'NewDeaths': 185,
#    'TotalDeaths': 36532,
#    'NewRecovered': 11040,
#    'TotalRecovered': 1167514,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 1520,
#    'TotalConfirmed': 121979,
#    'NewDeaths': 31,
#    'TotalDeaths': 1870,
#    'NewRecovered': 8319,
#    'TotalRecovered': 88388,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 27792,
#    'NewDeaths': 0,
#    'TotalDeaths': 907,
#    'NewRecovered': 4,
#    'TotalRecovered': 25511,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 6995,
#    'TotalConfirmed': 228683,
#    'NewDeaths': 62,
#    'TotalDeaths': 2116,
#    'NewRecovered': 6803,
#    'TotalRecovered': 149541,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 2597,
#    'TotalConfirmed': 83994,
#    'NewDeaths': 23,
#    'TotalDeaths': 1053,
#    'NewRecovered': 1354,
#    'TotalRecovered': 59465,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 7348,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 33,
#    'TotalRecovered': 5516,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 135,
#    'TotalConfirmed': 85317,
#    'NewDeaths': 0,
#    'TotalDeaths': 337,
#    'NewRecovered': 157,
#    'TotalRecovered': 83244,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 2364,
#    'TotalConfirmed': 441159,
#    'NewDeaths': 30,
#    'TotalDeaths': 6305,
#    'NewRecovered': 1934,
#    'TotalRecovered': 356722,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 253,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 2,
#    'TotalRecovered': 241,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 1382,
#    'TotalConfirmed': 119390,
#    'NewDeaths': 7,
#    'TotalDeaths': 1074,
#    'NewRecovered': 1266,
#    'TotalRecovered': 99584,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 4477,
#    'TotalConfirmed': 550264,
#    'NewDeaths': 171,
#    'TotalDeaths': 15196,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 60,
#    'TotalConfirmed': 5018,
#    'NewDeaths': 2,
#    'TotalDeaths': 102,
#    'NewRecovered': 63,
#    'TotalRecovered': 2743,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2916,
#    'NewDeaths': 0,
#    'TotalDeaths': 43,
#    'NewRecovered': 0,
#    'TotalRecovered': 2579,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 378,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 357,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 187,
#    'TotalConfirmed': 143756,
#    'NewDeaths': 14,
#    'TotalDeaths': 8889,
#    'NewRecovered': 358,
#    'TotalRecovered': 118691,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 1180,
#    'TotalConfirmed': 76757,
#    'NewDeaths': 64,
#    'TotalDeaths': 2153,
#    'NewRecovered': 1145,
#    'TotalRecovered': 41031,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 491,
#    'TotalConfirmed': 9594,
#    'NewDeaths': 1,
#    'TotalDeaths': 31,
#    'NewRecovered': 495,
#    'TotalRecovered': 7296,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 35918,
#    'TotalConfirmed': 5981767,
#    'NewDeaths': 606,
#    'TotalDeaths': 168061,
#    'NewRecovered': 22681,
#    'TotalRecovered': 5406066,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 148,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 145,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 3899,
#    'TotalConfirmed': 114435,
#    'NewDeaths': 119,
#    'TotalDeaths': 2649,
#    'NewRecovered': 847,
#    'TotalRecovered': 33327,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 16,
#    'TotalConfirmed': 2686,
#    'NewDeaths': 0,
#    'TotalDeaths': 68,
#    'NewRecovered': 4,
#    'TotalRecovered': 2476,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 641,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 575,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 304,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 291,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 632,
#    'TotalConfirmed': 23528,
#    'NewDeaths': 2,
#    'TotalDeaths': 435,
#    'NewRecovered': 667,
#    'TotalRecovered': 22177,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 4790,
#    'TotalConfirmed': 319162,
#    'NewDeaths': 76,
#    'TotalDeaths': 11313,
#    'NewRecovered': 4221,
#    'TotalRecovered': 257310,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 82,
#    'TotalConfirmed': 10082,
#    'NewDeaths': 0,
#    'TotalDeaths': 104,
#    'NewRecovered': 73,
#    'TotalRecovered': 9557,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 4907,
#    'NewDeaths': 0,
#    'TotalDeaths': 63,
#    'NewRecovered': 0,
#    'TotalRecovered': 1924,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 1620,
#    'NewDeaths': 0,
#    'TotalDeaths': 101,
#    'NewRecovered': 6,
#    'TotalRecovered': 1463,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 1454,
#    'TotalConfirmed': 536012,
#    'NewDeaths': 58,
#    'TotalDeaths': 14955,
#    'NewRecovered': 1108,
#    'TotalRecovered': 511874,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 29,
#    'TotalConfirmed': 91935,
#    'NewDeaths': 0,
#    'TotalDeaths': 4742,
#    'NewRecovered': 27,
#    'TotalRecovered': 86727,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 7487,
#    'TotalConfirmed': 1225490,
#    'NewDeaths': 198,
#    'TotalDeaths': 34761,
#    'NewRecovered': 7209,
#    'TotalRecovered': 1132393,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 592,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 5,
#    'TotalRecovered': 563,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 117,
#    'TotalConfirmed': 5632,
#    'NewDeaths': 1,
#    'TotalDeaths': 93,
#    'NewRecovered': 0,
#    'TotalRecovered': 3887,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 90,
#    'TotalConfirmed': 12008,
#    'NewDeaths': 0,
#    'TotalDeaths': 323,
#    'NewRecovered': 25,
#    'TotalRecovered': 11215,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 1219,
#    'TotalConfirmed': 128231,
#    'NewDeaths': 11,
#    'TotalDeaths': 1599,
#    'NewRecovered': 613,
#    'TotalRecovered': 78851,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 3164,
#    'TotalConfirmed': 93879,
#    'NewDeaths': 49,
#    'TotalDeaths': 1200,
#    'NewRecovered': 2192,
#    'TotalRecovered': 74865,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 21,
#    'TotalConfirmed': 7725,
#    'NewDeaths': 0,
#    'TotalDeaths': 131,
#    'NewRecovered': 29,
#    'TotalRecovered': 7201,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 268,
#    'TotalConfirmed': 7979,
#    'NewDeaths': 0,
#    'TotalDeaths': 41,
#    'NewRecovered': 0,
#    'TotalRecovered': 2021,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 6471,
#    'TotalConfirmed': 481755,
#    'NewDeaths': 134,
#    'TotalDeaths': 6874,
#    'NewRecovered': 11806,
#    'TotalRecovered': 379380,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 38,
#    'TotalConfirmed': 21083,
#    'NewDeaths': 0,
#    'TotalDeaths': 129,
#    'NewRecovered': 17,
#    'TotalRecovered': 20729,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 1297,
#    'TotalConfirmed': 67621,
#    'NewDeaths': 3,
#    'TotalDeaths': 773,
#    'NewRecovered': 1229,
#    'TotalRecovered': 52958,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5658,
#    'NewDeaths': 0,
#    'TotalDeaths': 61,
#    'NewRecovered': 1,
#    'TotalRecovered': 5550,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 68,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 41,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 1026,
#    'TotalConfirmed': 136183,
#    'NewDeaths': 8,
#    'TotalDeaths': 2301,
#    'NewRecovered': 656,
#    'TotalRecovered': 111527,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 996,
#    'TotalConfirmed': 183246,
#    'NewDeaths': 21,
#    'TotalDeaths': 13073,
#    'NewRecovered': 0,
#    'TotalRecovered': 160639,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 342,
#    'TotalConfirmed': 111955,
#    'NewDeaths': 13,
#    'TotalDeaths': 6508,
#    'NewRecovered': 143,
#    'TotalRecovered': 101564,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 144,
#    'TotalConfirmed': 37109,
#    'NewDeaths': 5,
#    'TotalDeaths': 1061,
#    'NewRecovered': 240,
#    'TotalRecovered': 33757,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5121,
#    'NewDeaths': 0,
#    'TotalDeaths': 85,
#    'NewRecovered': 0,
#    'TotalRecovered': 4975,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 527,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 5,
#    'TotalRecovered': 456,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 411,
#    'TotalConfirmed': 8715,
#    'NewDeaths': 1,
#    'TotalDeaths': 86,
#    'NewRecovered': 144,
#    'TotalRecovered': 5264,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 499,
#    'TotalConfirmed': 104427,
#    'NewDeaths': 6,
#    'TotalDeaths': 1607,
#    'NewRecovered': 390,
#    'TotalRecovered': 64983,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 35,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 32,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 351,
#    'TotalConfirmed': 20286,
#    'NewDeaths': 0,
#    'TotalDeaths': 374,
#    'NewRecovered': 0,
#    'TotalRecovered': 15300,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 21379,
#    'TotalConfirmed': 2137096,
#    'NewDeaths': 429,
#    'TotalDeaths': 47201,
#    'NewRecovered': 2179,
#    'TotalRecovered': 153145,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 32,
#    'TotalConfirmed': 9116,
#    'NewDeaths': 1,
#    'TotalDeaths': 59,
#    'NewRecovered': 8,
#    'TotalRecovered': 8965,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3705,
#    'NewDeaths': 0,
#    'TotalDeaths': 122,
#    'NewRecovered': 0,
#    'TotalRecovered': 3578,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 3697,
#    'TotalConfirmed': 93092,
#    'NewDeaths': 38,
#    'TotalDeaths': 853,
#    'NewRecovered': 2409,
#    'TotalRecovered': 73877,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 24041,
#    'TotalConfirmed': 891525,
#    'NewDeaths': 272,
#    'TotalDeaths': 13662,
#    'NewRecovered': 16689,
#    'TotalRecovered': 570961,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 174,
#    'TotalConfirmed': 50631,
#    'NewDeaths': 0,
#    'TotalDeaths': 323,
#    'NewRecovered': 393,
#    'TotalRecovered': 49103,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 3227,
#    'TotalConfirmed': 85261,
#    'NewDeaths': 59,
#    'TotalDeaths': 1347,
#    'NewRecovered': 0,
#    'TotalRecovered': 23074,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 36,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 30,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 685,
#    'TotalConfirmed': 117066,
#    'NewDeaths': 42,
#    'TotalDeaths': 4050,
#    'NewRecovered': 597,
#    'TotalRecovered': 106305,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12713,
#    'NewDeaths': 0,
#    'TotalDeaths': 75,
#    'NewRecovered': 0,
#    'TotalRecovered': 11689,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2421,
#    'NewDeaths': 0,
#    'TotalDeaths': 43,
#    'NewRecovered': 0,
#    'TotalRecovered': 2286,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 62,
#    'TotalConfirmed': 4976,
#    'NewDeaths': 1,
#    'TotalDeaths': 143,
#    'NewRecovered': 3,
#    'TotalRecovered': 3965,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 9208,
#    'NewDeaths': 0,
#    'TotalDeaths': 232,
#    'NewRecovered': 0,
#    'TotalRecovered': 7820,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 15,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 103488,
#    'NewDeaths': 0,
#    'TotalDeaths': 2839,
#    'NewRecovered': 0,
#    'TotalRecovered': 45082,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 4512,
#    'TotalConfirmed': 161461,
#    'NewDeaths': 92,
#    'TotalDeaths': 3472,
#    'NewRecovered': 1499,
#    'TotalRecovered': 36345,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 5231,
#    'NewDeaths': 0,
#    'TotalDeaths': 25,
#    'NewRecovered': 39,
#    'TotalRecovered': 4973,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 45882,
#    'TotalConfirmed': 9004365,
#    'NewDeaths': 584,
#    'TotalDeaths': 132162,
#    'NewRecovered': 44807,
#    'TotalRecovered': 8428409,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 4798,
#    'TotalConfirmed': 483518,
#    'NewDeaths': 97,
#    'TotalDeaths': 15600,
#    'NewRecovered': 4265,
#    'TotalRecovered': 406612,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 13223,
#    'TotalConfirmed': 815117,
#    'NewDeaths': 476,
#    'TotalDeaths': 43417,
#    'NewRecovered': 6721,
#    'TotalRecovered': 583704,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 2374,
#    'TotalConfirmed': 529226,
#    'NewDeaths': 39,
#    'TotalDeaths': 11834,
#    'NewRecovered': 2314,
#    'TotalRecovered': 457490,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 415,
#    'TotalConfirmed': 69473,
#    'NewDeaths': 4,
#    'TotalDeaths': 2010,
#    'NewRecovered': 0,
#    'TotalRecovered': 23364,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 718,
#    'TotalConfirmed': 327049,
#    'NewDeaths': 3,
#    'TotalDeaths': 2742,
#    'NewRecovered': 612,
#    'TotalRecovered': 315930,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 36176,
#    'TotalConfirmed': 1308528,
#    'NewDeaths': 653,
#    'TotalDeaths': 47870,
#    'NewRecovered': 17020,
#    'TotalRecovered': 498987,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 69,
#    'TotalConfirmed': 10088,
#    'NewDeaths': 2,
#    'TotalDeaths': 235,
#    'NewRecovered': 38,
#    'TotalRecovered': 5407,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 2382,
#    'TotalConfirmed': 125859,
#    'NewDeaths': 12,
#    'TotalDeaths': 1920,
#    'NewRecovered': 1237,
#    'TotalRecovered': 106074,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 5469,
#    'TotalConfirmed': 169395,
#    'NewDeaths': 84,
#    'TotalDeaths': 2053,
#    'NewRecovered': 5384,
#    'TotalRecovered': 100280,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 791,
#    'TotalConfirmed': 123888,
#    'NewDeaths': 0,
#    'TotalDeaths': 1945,
#    'NewRecovered': 311,
#    'TotalRecovered': 111483,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 1459,
#    'TotalConfirmed': 74145,
#    'NewDeaths': 17,
#    'TotalDeaths': 1330,
#    'NewRecovered': 780,
#    'TotalRecovered': 50658,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 363,
#    'TotalConfirmed': 30017,
#    'NewDeaths': 3,
#    'TotalDeaths': 501,
#    'NewRecovered': 165,
#    'TotalRecovered': 26263,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 485,
#    'TotalConfirmed': 138822,
#    'NewDeaths': 2,
#    'TotalDeaths': 859,
#    'NewRecovered': 587,
#    'TotalRecovered': 130426,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 422,
#    'TotalConfirmed': 68316,
#    'NewDeaths': 5,
#    'TotalDeaths': 1217,
#    'NewRecovered': 516,
#    'TotalRecovered': 59362,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 23,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 366,
#    'TotalConfirmed': 11722,
#    'NewDeaths': 4,
#    'TotalDeaths': 141,
#    'NewRecovered': 0,
#    'TotalRecovered': 1557,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 1909,
#    'TotalConfirmed': 111946,
#    'NewDeaths': 16,
#    'TotalDeaths': 868,
#    'NewRecovered': 876,
#    'TotalRecovered': 63404,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 2065,
#    'NewDeaths': 0,
#    'TotalDeaths': 44,
#    'NewRecovered': 0,
#    'TotalRecovered': 1273,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 1539,
#    'NewDeaths': 0,
#    'TotalDeaths': 82,
#    'NewRecovered': 3,
#    'TotalRecovered': 1331,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 541,
#    'TotalConfirmed': 76006,
#    'NewDeaths': 9,
#    'TotalDeaths': 1062,
#    'NewRecovered': 666,
#    'TotalRecovered': 46793,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 21,
#    'TotalConfirmed': 1072,
#    'NewDeaths': 0,
#    'TotalDeaths': 8,
#    'NewRecovered': 24,
#    'TotalRecovered': 865,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 1682,
#    'TotalConfirmed': 40492,
#    'NewDeaths': 18,
#    'TotalDeaths': 341,
#    'NewRecovered': 646,
#    'TotalRecovered': 10008,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 670,
#    'TotalConfirmed': 29243,
#    'NewDeaths': 6,
#    'TotalDeaths': 254,
#    'NewRecovered': 727,
#    'TotalRecovered': 19231,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Macao, SAR China',
#    'CountryCode': 'MO',
#    'Slug': 'macao-sar-china',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 1198,
#    'TotalConfirmed': 51213,
#    'NewDeaths': 26,
#    'TotalDeaths': 1423,
#    'NewRecovered': 621,
#    'TotalRecovered': 30204,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17310,
#    'NewDeaths': 0,
#    'TotalDeaths': 250,
#    'NewRecovered': 0,
#    'TotalRecovered': 16592,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 6002,
#    'NewDeaths': 0,
#    'TotalDeaths': 185,
#    'NewRecovered': 1,
#    'TotalRecovered': 5435,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 1290,
#    'TotalConfirmed': 51680,
#    'NewDeaths': 4,
#    'TotalDeaths': 326,
#    'NewRecovered': 878,
#    'TotalRecovered': 38132,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 68,
#    'TotalConfirmed': 12452,
#    'NewDeaths': 0,
#    'TotalDeaths': 45,
#    'NewRecovered': 69,
#    'TotalRecovered': 11475,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 60,
#    'TotalConfirmed': 4093,
#    'NewDeaths': 1,
#    'TotalDeaths': 142,
#    'NewRecovered': 14,
#    'TotalRecovered': 2997,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 140,
#    'TotalConfirmed': 8560,
#    'NewDeaths': 1,
#    'TotalDeaths': 104,
#    'NewRecovered': 117,
#    'TotalRecovered': 6301,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 24,
#    'TotalConfirmed': 8034,
#    'NewDeaths': 1,
#    'TotalDeaths': 168,
#    'NewRecovered': 1,
#    'TotalRecovered': 7554,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 494,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 433,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 4472,
#    'TotalConfirmed': 1019543,
#    'NewDeaths': 576,
#    'TotalDeaths': 100104,
#    'NewRecovered': 4336,
#    'TotalRecovered': 766361,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 1442,
#    'TotalConfirmed': 93961,
#    'NewDeaths': 19,
#    'TotalDeaths': 2091,
#    'NewRecovered': 1301,
#    'TotalRecovered': 75530,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 573,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 10,
#    'TotalRecovered': 497,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 50,
#    'TotalConfirmed': 555,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 6,
#    'TotalRecovered': 335,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 546,
#    'TotalConfirmed': 29577,
#    'NewDeaths': 6,
#    'TotalDeaths': 420,
#    'NewRecovered': 334,
#    'TotalRecovered': 18744,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 4559,
#    'TotalConfirmed': 311554,
#    'NewDeaths': 77,
#    'TotalDeaths': 5090,
#    'NewRecovered': 4641,
#    'TotalRecovered': 257992,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 94,
#    'TotalConfirmed': 14723,
#    'NewDeaths': 1,
#    'TotalDeaths': 120,
#    'NewRecovered': 95,
#    'TotalRecovered': 12849,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 1560,
#    'TotalConfirmed': 74882,
#    'NewDeaths': 26,
#    'TotalDeaths': 1676,
#    'NewRecovered': 869,
#    'TotalRecovered': 55633,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 52,
#    'TotalConfirmed': 13662,
#    'NewDeaths': 1,
#    'TotalDeaths': 141,
#    'NewRecovered': 30,
#    'TotalRecovered': 13182,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 2103,
#    'TotalConfirmed': 215020,
#    'NewDeaths': 17,
#    'TotalDeaths': 1276,
#    'NewRecovered': 2858,
#    'TotalRecovered': 185638,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 5645,
#    'TotalConfirmed': 467257,
#    'NewDeaths': 73,
#    'TotalDeaths': 8771,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 2013,
#    'NewDeaths': 0,
#    'TotalDeaths': 25,
#    'NewRecovered': 0,
#    'TotalRecovered': 1948,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5725,
#    'NewDeaths': 0,
#    'TotalDeaths': 159,
#    'NewRecovered': 0,
#    'TotalRecovered': 4225,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 1335,
#    'NewDeaths': 0,
#    'TotalDeaths': 70,
#    'NewRecovered': 2,
#    'TotalRecovered': 1153,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 146,
#    'TotalConfirmed': 65839,
#    'NewDeaths': 2,
#    'TotalDeaths': 1165,
#    'NewRecovered': 116,
#    'TotalRecovered': 61573,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 671,
#    'TotalConfirmed': 31441,
#    'NewDeaths': 5,
#    'TotalDeaths': 305,
#    'NewRecovered': 0,
#    'TotalRecovered': 17998,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 231,
#    'TotalConfirmed': 121360,
#    'NewDeaths': 5,
#    'TotalDeaths': 1365,
#    'NewRecovered': 392,
#    'TotalRecovered': 112406,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 2738,
#    'TotalConfirmed': 368665,
#    'NewDeaths': 313,
#    'TotalDeaths': 7561,
#    'NewRecovered': 868,
#    'TotalRecovered': 327542,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 1110,
#    'TotalConfirmed': 67296,
#    'NewDeaths': 9,
#    'TotalDeaths': 598,
#    'NewRecovered': 626,
#    'TotalRecovered': 57469,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 1256,
#    'TotalConfirmed': 151089,
#    'NewDeaths': 15,
#    'TotalDeaths': 2922,
#    'NewRecovered': 1560,
#    'TotalRecovered': 131315,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 604,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 586,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 856,
#    'TotalConfirmed': 74495,
#    'NewDeaths': 12,
#    'TotalDeaths': 1636,
#    'NewRecovered': 452,
#    'TotalRecovered': 53060,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 939931,
#    'NewDeaths': 0,
#    'TotalDeaths': 35317,
#    'NewRecovered': 4228,
#    'TotalRecovered': 871534,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 1333,
#    'TotalConfirmed': 413430,
#    'NewDeaths': 41,
#    'TotalDeaths': 7998,
#    'NewRecovered': 273,
#    'TotalRecovered': 374939,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 23975,
#    'TotalConfirmed': 796798,
#    'NewDeaths': 637,
#    'TotalDeaths': 12088,
#    'NewRecovered': 19003,
#    'TotalRecovered': 361886,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 6994,
#    'TotalConfirmed': 243009,
#    'NewDeaths': 69,
#    'TotalDeaths': 3701,
#    'NewRecovered': 4222,
#    'TotalRecovered': 157924,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 208,
#    'TotalConfirmed': 136649,
#    'NewDeaths': 0,
#    'TotalDeaths': 235,
#    'NewRecovered': 218,
#    'TotalRecovered': 133691,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 807,
#    'TotalConfirmed': 32022,
#    'NewDeaths': 14,
#    'TotalDeaths': 874,
#    'NewRecovered': 677,
#    'TotalRecovered': 19024,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 10108,
#    'TotalConfirmed': 393851,
#    'NewDeaths': 167,
#    'TotalDeaths': 9596,
#    'NewRecovered': 8203,
#    'TotalRecovered': 269590,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 23337,
#    'TotalConfirmed': 1998966,
#    'NewDeaths': 457,
#    'TotalDeaths': 34525,
#    'NewRecovered': 25052,
#    'TotalRecovered': 1514945,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 29,
#    'TotalConfirmed': 5572,
#    'NewDeaths': 0,
#    'TotalDeaths': 46,
#    'NewRecovered': 50,
#    'TotalRecovered': 5137,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Réunion',
#    'CountryCode': 'RE',
#    'Slug': 'réunion',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 19,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 20,
#    'TotalConfirmed': 203,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 60,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 84,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 78,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1358,
#    'NewDeaths': 0,
#    'TotalDeaths': 43,
#    'NewRecovered': 0,
#    'TotalRecovered': 1019,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 974,
#    'NewDeaths': 0,
#    'TotalDeaths': 16,
#    'NewRecovered': 0,
#    'TotalRecovered': 920,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 319,
#    'TotalConfirmed': 354527,
#    'NewDeaths': 19,
#    'TotalDeaths': 5729,
#    'NewRecovered': 441,
#    'TotalRecovered': 341956,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 15835,
#    'NewDeaths': 0,
#    'TotalDeaths': 329,
#    'NewRecovered': 7,
#    'TotalRecovered': 15440,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 6109,
#    'TotalConfirmed': 104097,
#    'NewDeaths': 29,
#    'TotalDeaths': 1110,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 163,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 2,
#    'TotalRecovered': 159,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2397,
#    'NewDeaths': 0,
#    'TotalDeaths': 74,
#    'NewRecovered': 0,
#    'TotalRecovered': 1823,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 58139,
#    'NewDeaths': 0,
#    'TotalDeaths': 28,
#    'NewRecovered': 6,
#    'TotalRecovered': 58052,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 1665,
#    'TotalConfirmed': 91578,
#    'NewDeaths': 0,
#    'TotalDeaths': 579,
#    'NewRecovered': 2771,
#    'TotalRecovered': 38695,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 2070,
#    'TotalConfirmed': 61034,
#    'NewDeaths': 45,
#    'TotalDeaths': 964,
#    'NewRecovered': 1646,
#    'TotalRecovered': 40153,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4382,
#    'NewDeaths': 0,
#    'TotalDeaths': 108,
#    'NewRecovered': 0,
#    'TotalRecovered': 3384,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 2514,
#    'TotalConfirmed': 759658,
#    'NewDeaths': 115,
#    'TotalDeaths': 20671,
#    'NewRecovered': 1010,
#    'TotalRecovered': 702544,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3016,
#    'NewDeaths': 0,
#    'TotalDeaths': 59,
#    'NewRecovered': 0,
#    'TotalRecovered': 1290,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 16233,
#    'TotalConfirmed': 1541574,
#    'NewDeaths': 252,
#    'TotalDeaths': 42291,
#    'NewRecovered': 0,
#    'TotalRecovered': 150376,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 439,
#    'TotalConfirmed': 18841,
#    'NewDeaths': 4,
#    'TotalDeaths': 73,
#    'NewRecovered': 316,
#    'TotalRecovered': 12903,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 252,
#    'TotalConfirmed': 15299,
#    'NewDeaths': 4,
#    'TotalDeaths': 1179,
#    'NewRecovered': 61,
#    'TotalRecovered': 9670,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 5284,
#    'NewDeaths': 0,
#    'TotalDeaths': 116,
#    'NewRecovered': 3,
#    'TotalRecovered': 5161,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 6156,
#    'NewDeaths': 0,
#    'TotalDeaths': 119,
#    'NewRecovered': 5,
#    'TotalRecovered': 5831,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 4609,
#    'TotalConfirmed': 201055,
#    'NewDeaths': 19,
#    'TotalDeaths': 6340,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 5007,
#    'TotalConfirmed': 285655,
#    'NewDeaths': 114,
#    'TotalDeaths': 3879,
#    'NewRecovered': 11600,
#    'TotalRecovered': 180700,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 72,
#    'TotalConfirmed': 6991,
#    'NewDeaths': 5,
#    'TotalDeaths': 363,
#    'NewRecovered': 56,
#    'TotalRecovered': 2924,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 609,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 4,
#    'TotalRecovered': 545,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 41,
#    'TotalConfirmed': 11772,
#    'NewDeaths': 0,
#    'TotalDeaths': 86,
#    'NewRecovered': 43,
#    'TotalRecovered': 11148,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 509,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 183,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 3892,
#    'NewDeaths': 0,
#    'TotalDeaths': 60,
#    'NewRecovered': 3,
#    'TotalRecovered': 3745,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 30,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 30,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 2771,
#    'NewDeaths': 0,
#    'TotalDeaths': 63,
#    'NewRecovered': 43,
#    'TotalRecovered': 2101,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 53,
#    'TotalConfirmed': 6233,
#    'NewDeaths': 0,
#    'TotalDeaths': 113,
#    'NewRecovered': 26,
#    'TotalRecovered': 5531,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 83772,
#    'NewDeaths': 0,
#    'TotalDeaths': 2541,
#    'NewRecovered': 0,
#    'TotalRecovered': 58229,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 4542,
#    'TotalConfirmed': 430170,
#    'NewDeaths': 123,
#    'TotalDeaths': 11943,
#    'NewRecovered': 2918,
#    'TotalRecovered': 364573,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 243,
#    'TotalConfirmed': 17148,
#    'NewDeaths': 1,
#    'TotalDeaths': 158,
#    'NewRecovered': 32,
#    'TotalRecovered': 8426,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 13630,
#    'TotalConfirmed': 600152,
#    'NewDeaths': 263,
#    'TotalDeaths': 10694,
#    'NewRecovered': 7921,
#    'TotalRecovered': 278190,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 1153,
#    'TotalConfirmed': 155254,
#    'NewDeaths': 2,
#    'TotalDeaths': 544,
#    'NewRecovered': 932,
#    'TotalRecovered': 146469,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 22936,
#    'TotalConfirmed': 1456940,
#    'NewDeaths': 502,
#    'TotalDeaths': 53870,
#    'NewRecovered': 36,
#    'TotalRecovered': 3242,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 187833,
#    'TotalConfirmed': 11715316,
#    'NewDeaths': 2015,
#    'TotalDeaths': 252535,
#    'NewRecovered': 59920,
#    'TotalRecovered': 4410709,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 81,
#    'TotalConfirmed': 4377,
#    'NewDeaths': 1,
#    'TotalDeaths': 69,
#    'NewRecovered': 75,
#    'TotalRecovered': 3479,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 63,
#    'TotalConfirmed': 70921,
#    'NewDeaths': 0,
#    'TotalDeaths': 601,
#    'NewRecovered': 0,
#    'TotalRecovered': 68123,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 315,
#    'TotalConfirmed': 98665,
#    'NewDeaths': 3,
#    'TotalDeaths': 863,
#    'NewRecovered': 301,
#    'TotalRecovered': 93691,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 1304,
#    'NewDeaths': 0,
#    'TotalDeaths': 35,
#    'NewRecovered': 18,
#    'TotalRecovered': 1142,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Western Sahara',
#    'CountryCode': 'EH',
#    'Slug': 'western-sahara',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 2086,
#    'NewDeaths': 1,
#    'TotalDeaths': 608,
#    'NewRecovered': 11,
#    'TotalRecovered': 1428,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 70,
#    'TotalConfirmed': 17350,
#    'NewDeaths': 0,
#    'TotalDeaths': 356,
#    'NewRecovered': 96,
#    'TotalRecovered': 16591,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}},
#   {'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 65,
#    'TotalConfirmed': 9046,
#    'NewDeaths': 4,
#    'TotalDeaths': 265,
#    'NewRecovered': 11,
#    'TotalRecovered': 8195,
#    'Date': '2020-11-20T07:21:07Z',
#    'Premium': {}}],
#  'Date': '2020-11-20T07:21:07Z'}

# %% [markdown]
# ### Normalizing Data

# %%
pd.json_normalize(covid1['Countries'],sep=",")
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan           377           44228
# 1           Albania          AL         albania           786           30623
# 2           Algeria          DZ         algeria          1023           71652
# 3           Andorra          AD         andorra            48            6066
# 4            Angola          AO          angola           212           14134
# ..              ...         ...             ...           ...             ...
# 186        Viet Nam          VN         vietnam             4            1304
# 187  Western Sahara          EH  western-sahara             0              10
# 188           Yemen          YE           yemen             3            2086
# 189          Zambia          ZM          zambia            70           17350
# 190        Zimbabwe          ZW        zimbabwe            65            9046
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            5         1650            55           35350
# 1           11          657           349           14565
# 2           18         2224           636           46962
# 3            0           76            72            5127
# 4            1          333           439            7062
# ..         ...          ...           ...             ...
# 186          0           35            18            1142
# 187          0            1             0               8
# 188          1          608            11            1428
# 189          0          356            96           16591
# 190          4          265            11            8195
#
#                      Date
# 0    2020-11-20T07:21:07Z
# 1    2020-11-20T07:21:07Z
# 2    2020-11-20T07:21:07Z
# 3    2020-11-20T07:21:07Z
# 4    2020-11-20T07:21:07Z
# ..                    ...
# 186  2020-11-20T07:21:07Z
# 187  2020-11-20T07:21:07Z
# 188  2020-11-20T07:21:07Z
# 189  2020-11-20T07:21:07Z
# 190  2020-11-20T07:21:07Z
#
# [191 rows x 10 columns]

# %%
df = pd.DataFrame(covid1['Countries'])
df
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan           377           44228
# 1           Albania          AL         albania           786           30623
# 2           Algeria          DZ         algeria          1023           71652
# 3           Andorra          AD         andorra            48            6066
# 4            Angola          AO          angola           212           14134
# ..              ...         ...             ...           ...             ...
# 186        Viet Nam          VN         vietnam             4            1304
# 187  Western Sahara          EH  western-sahara             0              10
# 188           Yemen          YE           yemen             3            2086
# 189          Zambia          ZM          zambia            70           17350
# 190        Zimbabwe          ZW        zimbabwe            65            9046
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            5         1650            55           35350
# 1           11          657           349           14565
# 2           18         2224           636           46962
# 3            0           76            72            5127
# 4            1          333           439            7062
# ..         ...          ...           ...             ...
# 186          0           35            18            1142
# 187          0            1             0               8
# 188          1          608            11            1428
# 189          0          356            96           16591
# 190          4          265            11            8195
#
#                      Date Premium
# 0    2020-11-20T07:21:07Z      {}
# 1    2020-11-20T07:21:07Z      {}
# 2    2020-11-20T07:21:07Z      {}
# 3    2020-11-20T07:21:07Z      {}
# 4    2020-11-20T07:21:07Z      {}
# ..                    ...     ...
# 186  2020-11-20T07:21:07Z      {}
# 187  2020-11-20T07:21:07Z      {}
# 188  2020-11-20T07:21:07Z      {}
# 189  2020-11-20T07:21:07Z      {}
# 190  2020-11-20T07:21:07Z      {}
#
# [191 rows x 11 columns]

# %% [markdown]
# ### Dropping Unnecessary Columns

# %%
covid2 = df.drop(columns =['CountryCode','Slug','Date','Premium'],axis=1)

# %% [markdown]
# ###  Base Map

# %%
m = folium.Map(tiles="Stamen Terrain", min_zoom=1.5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Obtaining Geodata

# %%
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes = f'{url}/world-countries.json'

# %% [markdown]
# ### Choropleth Map Layer

# %%
folium.Choropleth(
    geo_data=country_shapes,
    min_zoom=2,
    name='COVID-19',
    data=covid2,
    columns=['Country', 'TotalConfirmed'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    nan_fill_color='black',
    legend_name='Total Confirmed Covid Cases',
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Circular Markers

# %%
covid2.update(covid2['TotalConfirmed'].map('Total Confirmed:{}'.format))
covid2.update(covid2['TotalRecovered'].map('Total Recovered:{}'.format))

# %%
coordinates = pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv')
coordinates
# Out:
#       latitude   longitude            Country
# 0    33.939110   67.709953        Afghanistan
# 1    41.153332   20.168331            Albania
# 2    28.033886    1.659626            Algeria
# 3   -14.270972 -170.132217     American Samoa
# 4    42.546245    1.601554            Andorra
# ..         ...         ...                ...
# 239 -13.768752 -177.156097  Wallis and Futuna
# 240  24.215527  -12.885834     Western Sahara
# 241  15.552727   48.516388              Yemen
# 242 -13.133897   27.849332             Zambia
# 243 -19.015438   29.154857           Zimbabwe
#
# [244 rows x 3 columns]

# %%
covid_final= pd.merge(covid2,coordinates,on='Country')

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude, point.longitude],
                        radius=5,
                        weight=2,
                        popup = [point.Country,point.TotalConfirmed,point.TotalRecovered],
                        fill_color='#000000').add_to(m)

# %%
covid_final.apply(plotDot, axis = 1)

m.fit_bounds(m.get_bounds())

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Base Map

# %%
m1 = folium.Map(tiles='StamenToner', min_zoom=2)

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
deaths=covid_final['TotalDeaths'].astype(float)

# %%
lat=covid_final['latitude'].astype(float)

# %%
lon=covid_final['longitude'].astype(float)

# %% [markdown]
# ### Generating Heat Map Layer

# %%
m1.add_child(HeatMap(zip(lat,lon,deaths),radius=0))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generating Circular Marker

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude, point.longitude],
                        radius=5,
                        weight=2,
                        popup = [point.Country,point.TotalDeaths],
                        fill_color='#000000').add_to(m1)

covid_final.apply(plotDot, axis = 1)

m1.fit_bounds(m1.get_bounds())

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
